# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("kc_house_data.csv")

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
data.describe().T
# Out:
#                  count          mean           std           min  \
# id             21613.0  4.580302e+09  2.876566e+09  1.000102e+06
# price          21613.0  5.400881e+05  3.671272e+05  7.500000e+04
# bedrooms       21613.0  3.370842e+00  9.300618e-01  0.000000e+00
# bathrooms      21613.0  2.114757e+00  7.701632e-01  0.000000e+00
# sqft_living    21613.0  2.079900e+03  9.184409e+02  2.900000e+02
# sqft_lot       21613.0  1.510697e+04  4.142051e+04  5.200000e+02
# floors         21613.0  1.494309e+00  5.399889e-01  1.000000e+00
# waterfront     21613.0  7.541757e-03  8.651720e-02  0.000000e+00
# view           21613.0  2.343034e-01  7.663176e-01  0.000000e+00
# condition      21613.0  3.409430e+00  6.507430e-01  1.000000e+00
# grade          21613.0  7.656873e+00  1.175459e+00  1.000000e+00
# sqft_above     21613.0  1.788391e+03  8.280910e+02  2.900000e+02
# sqft_basement  21613.0  2.915090e+02  4.425750e+02  0.000000e+00
# ...

# %%
plt.figure(figsize=(18,10))
sns.heatmap(data.corr(),annot=True,cmap="mako")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,4))
sns.barplot(data=data,x=data["view"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
plt.figure(figsize=(8,4))
sns.lineplot(data=data,x=data["view"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='view', ylabel='price'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="waterfront", y="price", data=data)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='price'>

# %%
sns.scatterplot(data=data,x=data["bedrooms"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.countplot(x=data["bedrooms"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.boxplot(x=data["bedrooms"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
plt.figure(figsize=(20,10))
sns.violinplot(x=data["bedrooms"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='price'>

# %%
sns.scatterplot(data=data, x=data["bathrooms"], y=data["price"])
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='price'>

# %%
sns.jointplot(data=data, x=data["bathrooms"], y=data["price"],color="green")

# %%
sns.regplot(x="price", y="sqft_living", data=data)
plt.ylim(0,)
# Out:
# (0.0, 15751.067825165253)

# %%
sns.regplot(x="price", y="sqft_lot", data=data)
plt.ylim(0,)
# Out:
# (0.0, 1733900.95)

# %%
plt.figure(figsize=(10,5))
sns.lineplot(x=data["floors"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='floors', ylabel='price'>

# %%
sns.countplot(data["floors"])
# Out:
# <AxesSubplot:xlabel='floors', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(y = data["condition"])
# Out:
# <AxesSubplot:xlabel='count', ylabel='condition'>

# %%
sns.barplot(x="condition",y="price",data=data)
# Out:
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=data["condition"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='condition', ylabel='price'>

# %%
sns.countplot(data["grade"])
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %%
sns.jointplot(x=data["grade"],y=data["price"],color="purple")

# %%
sns.lineplot(x=data["grade"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='grade', ylabel='price'>

# %%
data["yr_built"].describe()
# Out:
# count    21613.000000
# mean      1971.005136
# std         29.373411
# min       1900.000000
# 25%       1951.000000
# 50%       1975.000000
# 75%       1997.000000
# max       2015.000000
# Name: yr_built, dtype: float64

# %%
data["yr_built"].unique()
# Out:
# array([1955, 1951, 1933, 1965, 1987, 2001, 1995, 1963, 1960, 2003, 1942,
#        1927, 1977, 1900, 1979, 1994, 1916, 1921, 1969, 1947, 1968, 1985,
#        1941, 1915, 1909, 1948, 2005, 1929, 1981, 1930, 1904, 1996, 2000,
#        1984, 2014, 1922, 1959, 1966, 1953, 1950, 2008, 1991, 1954, 1973,
#        1925, 1989, 1972, 1986, 1956, 2002, 1992, 1964, 1952, 1961, 2006,
#        1988, 1962, 1939, 1946, 1967, 1975, 1980, 1910, 1983, 1978, 1905,
#        1971, 2010, 1945, 1924, 1990, 1914, 1926, 2004, 1923, 2007, 1976,
#        1949, 1999, 1901, 1993, 1920, 1997, 1943, 1957, 1940, 1918, 1928,
#        1974, 1911, 1936, 1937, 1982, 1908, 1931, 1998, 1913, 2013, 1907,
#        1958, 2012, 1912, 2011, 1917, 1932, 1944, 1902, 2009, 1903, 1970,
#        2015, 1934, 1938, 1919, 1906, 1935])

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x=data["yr_built"],y=data["price"])
plt.xlabel("Yapım Yılı")
plt.ylabel("Fiyat")
# Out:
# Text(0, 0.5, 'Fiyat')

# %%
plt.figure(figsize=(15,8))
sns.lineplot(x=data["yr_built"],y=data["price"])
plt.xlim(2000,)
plt.xlabel("Yapım Yılı (2000 ve Sonrası)")
plt.ylabel("Fiyat")
# Out:
# Text(0, 0.5, 'Fiyat')

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=data["yr_built"],y=data["price"])
plt.xlabel("Yapım Yılı")
plt.ylabel("Fiyat")
# Out:
# Text(0, 0.5, 'Fiyat')

# %%
plt.figure(figsize=(15,8))
plt.subplot(2,2,1)
sns.lineplot(x=data["yr_renovated"],y=data["price"])
plt.xlim(1900,)
plt.subplot(2,2,2)
sns.lineplot(x=data["yr_renovated"],y=data["price"])
plt.xlim(1950,)
plt.subplot(2,2,3)
sns.lineplot(x=data["yr_renovated"],y=data["price"])
plt.xlim(1970,)
plt.subplot(2,2,4)
sns.lineplot(x=data["yr_renovated"],y=data["price"])
plt.xlim(2000,)
# Out:
# (2000.0, 2115.75)

# %%
np.linspace(data["price"].min(),data["price"].max(),10)
# Out:
# array([  75000.        ,  922222.22222222, 1769444.44444444,
#        2616666.66666667, 3463888.88888889, 4311111.11111111,
#        5158333.33333333, 6005555.55555556, 6852777.77777778,
#        7700000.        ])

# %%
data["Type"] = data["price"]
data["Type"].loc[data["price"]<=922222] = "Type 1"

data["Type"].loc[(data["price"]>922222)&(data["price"]<=1769444)] = "Type 2"
data["Type"].loc[(data["price"]>1769444)&(data["price"]<=2616666)] = "Type 3"
data["Type"].loc[(data["price"]>2616666)&(data["price"]<=3463888)] = "Type 4"

data["Type"].loc[(data["price"]>3463888)&(data["price"]<=4311111)] = "Type 5"
data["Type"].loc[(data["price"]>4311111)&(data["price"]<=5158333)] = "Type 6"
data["Type"].loc[(data["price"]>5158333)&(data["price"]<=6005555)] = "Type 7"

data["Type"].loc[(data["price"]>6005555)&(data["price"]<=6852777)] = "Type 8"
data["Type"].loc[(data["price"]>6852777)&(data["price"]<=7700000)] = "Type 9"

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"])
# Out:
# <AxesSubplot:xlabel='lat', ylabel='long'>

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 2")
plt.title("Type 2")
plt.subplot(2,2,2)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 3")
plt.title("Type 3")
plt.subplot(2,2,3)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 4")
plt.title("Type 4")
plt.subplot(2,2,4)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 5")
plt.title("Type 5")
# Out:
# Text(0.5, 1.0, 'Type 5')

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 6")
plt.title("Type 6")
plt.subplot(2,2,2)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 7")
plt.title("Type 7")
plt.subplot(2,2,3)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 8")
plt.title("Type 8")
plt.subplot(2,2,4)
sns.scatterplot(x=data["lat"],y=data["long"],hue=data["Type"]=="Type 9")
plt.title("Type 9")
# Out:
# Text(0.5, 1.0, 'Type 9')

# %%
fig = sns.FacetGrid(data,hue="Type",aspect=4)
fig.map(sns.kdeplot,"price",shade=True)
high = data["price"].max()
fig.set(xlim=(0,high))
fig.add_legend()

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=data["sqft_living15"],y=data["price"])
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x=data["sqft_living15"],y=data["price"])

# %%
plt.figure(figsize=(20,10))
sns.regplot(x=data["sqft_living15"],y=data["price"],color="green",marker="*")
# Out:
# <AxesSubplot:xlabel='sqft_living15', ylabel='price'>

# %%
import datetime
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...        1180              0
# 1      7242     2.0           0     0  ...        2170            400
# 2     10000     1.0           0     0  ...         770              0
# 3      5000     1.0           0     0  ...        1050            910
# 4      8080     1.0           0     0  ...        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
for  i in data["date"]:
    clean_date = i[0:8]

# %%
data["date"]= pd.to_datetime(clean_date,format="%Y%m%d")

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x=data["bedrooms"],y=data["sqft_living"])

# %%
plt.figure(figsize=(20,10))
sns.barplot(x=data["bedrooms"],y=data["sqft_living"])
sns.lineplot(x=data["bedrooms"],y=data["sqft_living"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,5))
sns.countplot(data["grade"],hue=data["waterfront"])
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="view",y="grade",data=data)
# Out:
# <AxesSubplot:xlabel='view', ylabel='grade'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=data, x=data["condition"], y=data["yr_built"],color="pink")
plt.ylim(data.yr_built.min(),data.yr_built.max())
# Out:
# (1900.0, 2015.0)

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=data, x=data["condition"], y=data["yr_renovated"],color="violet")
plt.ylim(data.yr_renovated.min(),data.yr_renovated.max())
# Out:
# (0.0, 2015.0)

# %%
plt.figure(figsize=(20,10))
sns.jointplot(x=data["sqft_basement"],y=data["grade"],color="purple")

# %%
plt.figure(figsize=(12,6))
sns.lineplot(x=data["bedrooms"],y=data["floors"])
# Out:
# <AxesSubplot:xlabel='bedrooms', ylabel='floors'>

# %%
sns.countplot(data["waterfront"])
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.barplot(x="waterfront",y="sqft_living",data=data,color="red")
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='sqft_living'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x="waterfront", y="bathrooms", data=data)
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='bathrooms'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data=data,x=data["bathrooms"],y=data["sqft_living"],color="red")
sns.lineplot(data=data,x=data["bathrooms"],y=data["sqft_living"],color="red")
# Out:
# <AxesSubplot:xlabel='bathrooms', ylabel='sqft_living'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data["waterfront"],hue=data["view"])
# Out:
# <AxesSubplot:xlabel='waterfront', ylabel='count'>

# %%
plt.figure(figsize=(15,8))
sns.barplot(x=data["grade"],y=data["sqft_above"])
sns.lineplot(x=data["grade"],y=data["sqft_above"])
# Out:
# <AxesSubplot:xlabel='grade', ylabel='sqft_above'>

# %%
plt.figure(figsize=(20,10))
plt.subplot(2,2,1)
sns.lineplot(x=data["grade"],y=data["sqft_basement"])
plt.subplot(2,2,2)
sns.lineplot(x=data["grade"],y=data["sqft_basement"])
sns.barplot(x=data["grade"],y=data["sqft_basement"],palette="rocket")
# Out:
# <AxesSubplot:xlabel='grade', ylabel='sqft_basement'>

# %%
plt.figure(figsize=(14,10))
sns.violinplot(data=data,x=data["view"],y=data["floors"])
# Out:
# <AxesSubplot:xlabel='view', ylabel='floors'>
